# %% [markdown]
# # import libraries

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, auc, precision_recall_curve, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE, ADASYN
from collections import Counter

# %% [markdown]
# # read data

# %%
train = pd.read_parquet('./datafiles/train_reduced.parquet')
test = pd.read_parquet('./datafiles/test_reduced.parquet')

# %%
print(len(train))
print(len(test))
# Out:
# 96821
# 25017

# %%
x_train = train.drop(columns=["transcript_id", "transcript_position", "seq", "gene_id", "label"])
y_train = train[['label']]

# %%
x_test = test.drop(columns=["transcript_id", "transcript_position", "seq", "gene_id", "label"])
y_test = test[['label']]

# %%
print(x_train)
print(y_train)
# Out:
#         whole_mean_dt_1  whole_mean_sd_1  whole_mean_curr_1  whole_mean_dt_2  \
# 18             0.007340         2.977180         108.360000         0.007782
# 19             0.008988         3.961489         118.638298         0.007403
# 20             0.011065         7.299608         115.549020         0.009377
# 21             0.006904         2.803571         119.142857         0.010334
# 22             0.006961         4.949231         108.373077         0.009155
# ...                 ...              ...                ...              ...
# 121833         0.009594         3.294164         118.232877         0.007300
# 121834         0.008393         4.511014         110.969565         0.010305
# 121835         0.008161         3.918438         113.968750         0.006877
# 121836         0.008044         3.191228         109.354386         0.007419
# 121837         0.008788         4.090577         105.807692         0.006907
#
#         whole_mean_sd_2  whole_mean_curr_2  whole_mean_dt_3  whole_mean_sd_3  \
# 18             2.608600         106.584000         0.007045         1.888520
# 19             6.045319         122.489362         0.006636         3.112340
# 20             5.986667         125.666667         0.006474         2.857647
# 21             5.950893         123.821429         0.010214         2.679821
# 22             5.005962         123.750000         0.011251         4.740577
# ...                 ...                ...              ...              ...
# 121833         4.929726         116.342466         0.006555         4.005616
# 121834         9.105797         114.927536         0.005568         3.644638
# 121835         4.759687         113.562500         0.006410         2.181562
# 121836         6.552982         123.263158         0.006472         2.540877
# 121837         8.702885         113.134615         0.008337         2.576731
#
#         whole_mean_curr_3  whole_median_dt_1  ...  cluster_2_min_sd_3  \
# 18              94.174000           0.005475  ...               0.781
# 19              83.229787           0.007970  ...               1.720
# 20              89.605882           0.008710  ...               1.540
# 21              90.810714           0.005310  ...               1.420
# 22              83.025000           0.004920  ...               3.010
# ...                   ...                ...  ...                 ...
# 121833          82.004110           0.008170  ...               1.480
# 121834          80.497101           0.006180  ...               1.760
# 121835          84.190625           0.006970  ...               1.040
# 121836          82.289474           0.006600  ...               1.190
# 121837          78.536538           0.007090  ...               1.330
#
#         cluster_2_min_curr_3  cluster_2_sd_dt_1  cluster_2_sd_sd_1  \
# 18                      90.1           0.004753           2.295391
# 19                      78.4           0.005742           1.113159
# 20                      86.7           0.007872           1.764011
# 21                      89.3           0.004021           1.846205
# 22                      80.2           0.004073           1.011763
# ...                      ...                ...                ...
# 121833                  76.0           0.004391           1.174303
# 121834                  75.0           0.005394           1.979405
# 121835                  78.2           0.005299           1.174073
# 121836                  77.6           0.004695           0.796188
# 121837                  75.2           0.006581           1.977663
#
#         cluster_2_sd_curr_1  cluster_2_sd_dt_2  cluster_2_sd_sd_2  \
# 18                 2.368845           0.003721           0.605664
# 19                 2.396142           0.002825           1.860764
# 20                 2.193497           0.004701           1.673851
# 21                 1.564059           0.003473           3.109129
# 22                 3.794733           0.003542           1.812695
# ...                     ...                ...                ...
# 121833             2.235561           0.004556           1.678792
# 121834             3.978471           0.004743           1.382768
# 121835             2.582586           0.004565           1.179861
# 121836             4.831773           0.002296           2.261881
# 121837             4.798291           0.003249           2.177636
#
#         cluster_2_sd_curr_2  cluster_2_sd_sd_3  cluster_2_sd_curr_3
# 18                 1.576356           0.442328             2.147127
# 19                 2.381905           1.457417             2.129269
# 20                 1.558126           0.891852             1.524671
# 21                 2.829401           1.089678             1.202462
# 22                 2.289105           0.998551             1.012373
# ...                     ...                ...                  ...
# 121833             2.706338           2.342449             3.736387
# 121834             2.568104           0.796583             3.087344
# 121835             1.791664           1.046608             1.858941
# 121836             2.397088           0.543752             1.941561
# 121837             3.596874           1.326168             3.045585
#
# [96821 rows x 113 columns]
#         label
# 18          0
# 19          0
# 20          0
# 21          0
# 22          0
# ...       ...
# 121833      1
# 121834      0
# 121835      1
# 121836      0
# 121837      0
#
# [96821 rows x 1 columns]

# %% [markdown]
# # original dataset

# %% [markdown]
# ## logistic regression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lr.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, lr.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lr.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lr.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23934    29]
#  [ 1022    32]]
# roc auc: 0.7898
# pr auc: 0.2181

# %% [markdown]
# ## decision tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, dt.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, dt.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, dt.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, dt.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23033   930]
#  [  749   305]]
# roc auc: 0.6253
# pr auc: 0.2831

# %% [markdown]
# ## random forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, rf.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, rf.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, rf.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, rf.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23901    62]
#  [  901   153]]
# roc auc: 0.8967
# pr auc: 0.4493

# %% [markdown]
# ## xgboost

# %%
xgb = XGBClassifier()
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, xgb.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, xgb.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, xgb.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, xgb.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23741   222]
#  [  747   307]]
# roc auc: 0.9112
# pr auc: 0.4257

# %% [markdown]
# ## lightgbm

# %%
lgbm = LGBMClassifier()
lgbm.fit(x_train, y_train.values.ravel())
# Out:
# LGBMClassifier()

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_auc_score, average_precision_score, make_scorer
import numpy as np

lgb_model = LGBMClassifier()
# y_train = y_train.values.ravel()

# Define the hyperparameter distribution
param_dist = {
    'num_leaves': np.arange(10, 100, 10),
    'min_data_in_leaf': np.arange(100, 1000, 100),
    'max_depth': [-1, 10, 20],
    'verbose': [-1]
}

# Custom scoring function that sums the roc_auc and pr_auc
def combined_auc_score(y_true, y_proba):
    roc_auc = roc_auc_score(y_true, y_proba)
    pr_auc = average_precision_score(y_true, y_proba)
    return (roc_auc + pr_auc)/2

# Create a custom scorer using make_scorer, with needs_proba=True since we need predicted probabilities
combined_scorer = make_scorer(combined_auc_score, needs_proba=True)

# Set up RandomizedSearchCV with the custom combined scorer
random_search = RandomizedSearchCV(
    estimator=lgb_model, 
    param_distributions=param_dist, 
    n_iter=50,
    scoring=combined_scorer, 
    cv=5, 
    random_state=42,
    verbose = 3
)

# Perform the random search
random_search.fit(x_train, y_train)

# Output the best parameters based on the combined auc score
print(f"Best parameters found (based on combined AUC score): {random_search.best_params_}")
print(f"Best combined AUC score (roc_auc + pr_auc): {random_search.best_score_}")

lgbm = random_search.best_estimator_
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=70, verbose=-1;, score=0.698 total time=   1.9s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=70, verbose=-1;, score=0.677 total time=   1.8s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=70, verbose=-1;, score=0.671 total time=   1.9s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=70, verbose=-1;, score=0.683 total time=   1.9s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=70, verbose=-1;, score=0.671 total time=   1.8s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=100, num_leaves=70, verbose=-1;, score=0.699 total time=   1.8s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=100, num_leaves=70, verbose=-1;, score=0.680 total time=   1.8s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=100, num_leaves=70, verbose=-1;, score=0.674 total time=   1.7s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=100, num_leaves=70, verbose=-1;, score=0.683 total time=   1.7s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=100, num_leaves=70, verbose=-1;, score=0.675 total time=   1.7s
# [CV 1/5] END max_depth=10, min_data_in_leaf=800, num_leaves=90, verbose=-1;, score=0.701 total time=   1.5s
# [CV 2/5] END max_depth=10, min_data_in_leaf=800, num_leaves=90, verbose=-1;, score=0.689 total time=   1.9s
# [CV 3/5] END max_depth=10, min_data_in_leaf=800, num_leaves=90, verbose=-1;, score=0.673 total time=   1.7s
# [CV 4/5] END max_depth=10, min_data_in_leaf=800, num_leaves=90, verbose=-1;, score=0.686 total time=   1.6s
# [CV 5/5] END max_depth=10, min_data_in_leaf=800, num_leaves=90, verbose=-1;, score=0.674 total time=   1.6s
# [CV 1/5] END max_depth=20, min_data_in_leaf=800, num_leaves=80, verbose=-1;, score=0.701 total time=   1.9s
# [CV 2/5] END max_depth=20, min_data_in_leaf=800, num_leaves=80, verbose=-1;, score=0.688 total time=   2.0s
# [CV 3/5] END max_depth=20, min_data_in_leaf=800, num_leaves=80, verbose=-1;, score=0.670 total time=   2.0s
# [CV 4/5] END max_depth=20, min_data_in_leaf=800, num_leaves=80, verbose=-1;, score=0.687 total time=   1.9s
# [CV 5/5] END max_depth=20, min_data_in_leaf=800, num_leaves=80, verbose=-1;, score=0.676 total time=   1.9s
# [CV 1/5] END max_depth=20, min_data_in_leaf=900, num_leaves=50, verbose=-1;, score=0.697 total time=   1.6s
# [CV 2/5] END max_depth=20, min_data_in_leaf=900, num_leaves=50, verbose=-1;, score=0.682 total time=   1.6s
# [CV 3/5] END max_depth=20, min_data_in_leaf=900, num_leaves=50, verbose=-1;, score=0.675 total time=   1.6s
# [CV 4/5] END max_depth=20, min_data_in_leaf=900, num_leaves=50, verbose=-1;, score=0.689 total time=   1.6s
# [CV 5/5] END max_depth=20, min_data_in_leaf=900, num_leaves=50, verbose=-1;, score=0.678 total time=   1.6s
# [CV 1/5] END max_depth=20, min_data_in_leaf=200, num_leaves=50, verbose=-1;, score=0.693 total time=   1.5s
# [CV 2/5] END max_depth=20, min_data_in_leaf=200, num_leaves=50, verbose=-1;, score=0.684 total time=   1.5s
# [CV 3/5] END max_depth=20, min_data_in_leaf=200, num_leaves=50, verbose=-1;, score=0.672 total time=   1.5s
# [CV 4/5] END max_depth=20, min_data_in_leaf=200, num_leaves=50, verbose=-1;, score=0.684 total time=   1.5s
# [CV 5/5] END max_depth=20, min_data_in_leaf=200, num_leaves=50, verbose=-1;, score=0.673 total time=   1.5s
# [CV 1/5] END max_depth=20, min_data_in_leaf=600, num_leaves=90, verbose=-1;, score=0.694 total time=   2.0s
# [CV 2/5] END max_depth=20, min_data_in_leaf=600, num_leaves=90, verbose=-1;, score=0.686 total time=   2.0s
# [CV 3/5] END max_depth=20, min_data_in_leaf=600, num_leaves=90, verbose=-1;, score=0.673 total time=   2.0s
# [CV 4/5] END max_depth=20, min_data_in_leaf=600, num_leaves=90, verbose=-1;, score=0.684 total time=   2.0s
# [CV 5/5] END max_depth=20, min_data_in_leaf=600, num_leaves=90, verbose=-1;, score=0.681 total time=   2.0s
# [CV 1/5] END max_depth=10, min_data_in_leaf=800, num_leaves=70, verbose=-1;, score=0.701 total time=   1.6s
# [CV 2/5] END max_depth=10, min_data_in_leaf=800, num_leaves=70, verbose=-1;, score=0.688 total time=   1.5s
# [CV 3/5] END max_depth=10, min_data_in_leaf=800, num_leaves=70, verbose=-1;, score=0.678 total time=   1.5s
# [CV 4/5] END max_depth=10, min_data_in_leaf=800, num_leaves=70, verbose=-1;, score=0.688 total time=   1.5s
# [CV 5/5] END max_depth=10, min_data_in_leaf=800, num_leaves=70, verbose=-1;, score=0.677 total time=   1.5s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=10, verbose=-1;, score=0.678 total time=   0.8s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=10, verbose=-1;, score=0.676 total time=   0.8s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=10, verbose=-1;, score=0.666 total time=   0.8s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=10, verbose=-1;, score=0.675 total time=   0.8s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=10, verbose=-1;, score=0.659 total time=   0.8s
# [CV 1/5] END max_depth=10, min_data_in_leaf=400, num_leaves=60, verbose=-1;, score=0.702 total time=   1.5s
# [CV 2/5] END max_depth=10, min_data_in_leaf=400, num_leaves=60, verbose=-1;, score=0.680 total time=   1.5s
# [CV 3/5] END max_depth=10, min_data_in_leaf=400, num_leaves=60, verbose=-1;, score=0.676 total time=   1.5s
# [CV 4/5] END max_depth=10, min_data_in_leaf=400, num_leaves=60, verbose=-1;, score=0.684 total time=   1.5s
# [CV 5/5] END max_depth=10, min_data_in_leaf=400, num_leaves=60, verbose=-1;, score=0.677 total time=   1.5s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.682 total time=   0.8s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.675 total time=   0.8s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.668 total time=   0.8s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.673 total time=   0.8s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.658 total time=   0.8s
# [CV 1/5] END max_depth=20, min_data_in_leaf=600, num_leaves=30, verbose=-1;, score=0.697 total time=   1.2s
# [CV 2/5] END max_depth=20, min_data_in_leaf=600, num_leaves=30, verbose=-1;, score=0.686 total time=   1.2s
# [CV 3/5] END max_depth=20, min_data_in_leaf=600, num_leaves=30, verbose=-1;, score=0.679 total time=   1.2s
# [CV 4/5] END max_depth=20, min_data_in_leaf=600, num_leaves=30, verbose=-1;, score=0.687 total time=   1.2s
# [CV 5/5] END max_depth=20, min_data_in_leaf=600, num_leaves=30, verbose=-1;, score=0.670 total time=   1.2s
# [CV 1/5] END max_depth=20, min_data_in_leaf=800, num_leaves=30, verbose=-1;, score=0.704 total time=   1.2s
# [CV 2/5] END max_depth=20, min_data_in_leaf=800, num_leaves=30, verbose=-1;, score=0.685 total time=   1.2s
# [CV 3/5] END max_depth=20, min_data_in_leaf=800, num_leaves=30, verbose=-1;, score=0.670 total time=   1.2s
# [CV 4/5] END max_depth=20, min_data_in_leaf=800, num_leaves=30, verbose=-1;, score=0.687 total time=   1.2s
# [CV 5/5] END max_depth=20, min_data_in_leaf=800, num_leaves=30, verbose=-1;, score=0.670 total time=   1.2s
# [CV 1/5] END max_depth=20, min_data_in_leaf=100, num_leaves=90, verbose=-1;, score=0.699 total time=   2.0s
# [CV 2/5] END max_depth=20, min_data_in_leaf=100, num_leaves=90, verbose=-1;, score=0.675 total time=   2.0s
# [CV 3/5] END max_depth=20, min_data_in_leaf=100, num_leaves=90, verbose=-1;, score=0.669 total time=   2.1s
# [CV 4/5] END max_depth=20, min_data_in_leaf=100, num_leaves=90, verbose=-1;, score=0.687 total time=   2.0s
# [CV 5/5] END max_depth=20, min_data_in_leaf=100, num_leaves=90, verbose=-1;, score=0.677 total time=   2.0s
# [CV 1/5] END max_depth=10, min_data_in_leaf=100, num_leaves=20, verbose=-1;, score=0.692 total time=   1.0s
# [CV 2/5] END max_depth=10, min_data_in_leaf=100, num_leaves=20, verbose=-1;, score=0.679 total time=   1.0s
# [CV 3/5] END max_depth=10, min_data_in_leaf=100, num_leaves=20, verbose=-1;, score=0.671 total time=   1.0s
# [CV 4/5] END max_depth=10, min_data_in_leaf=100, num_leaves=20, verbose=-1;, score=0.676 total time=   1.0s
# [CV 5/5] END max_depth=10, min_data_in_leaf=100, num_leaves=20, verbose=-1;, score=0.665 total time=   1.0s
# [CV 1/5] END max_depth=10, min_data_in_leaf=900, num_leaves=90, verbose=-1;, score=0.696 total time=   1.4s
# [CV 2/5] END max_depth=10, min_data_in_leaf=900, num_leaves=90, verbose=-1;, score=0.682 total time=   1.4s
# [CV 3/5] END max_depth=10, min_data_in_leaf=900, num_leaves=90, verbose=-1;, score=0.676 total time=   1.4s
# [CV 4/5] END max_depth=10, min_data_in_leaf=900, num_leaves=90, verbose=-1;, score=0.689 total time=   1.4s
# [CV 5/5] END max_depth=10, min_data_in_leaf=900, num_leaves=90, verbose=-1;, score=0.680 total time=   1.4s
# [CV 1/5] END max_depth=20, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.697 total time=   1.2s
# [CV 2/5] END max_depth=20, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.683 total time=   1.2s
# [CV 3/5] END max_depth=20, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.675 total time=   1.2s
# [CV 4/5] END max_depth=20, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.687 total time=   1.2s
# [CV 5/5] END max_depth=20, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.672 total time=   1.2s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.695 total time=   1.7s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.679 total time=   1.7s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.673 total time=   1.7s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.689 total time=   1.7s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.678 total time=   1.9s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=40, verbose=-1;, score=0.699 total time=   1.4s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=40, verbose=-1;, score=0.683 total time=   1.4s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=40, verbose=-1;, score=0.673 total time=   1.4s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=40, verbose=-1;, score=0.687 total time=   1.4s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=40, verbose=-1;, score=0.674 total time=   1.4s
# [CV 1/5] END max_depth=10, min_data_in_leaf=600, num_leaves=20, verbose=-1;, score=0.696 total time=   1.0s
# [CV 2/5] END max_depth=10, min_data_in_leaf=600, num_leaves=20, verbose=-1;, score=0.681 total time=   1.0s
# [CV 3/5] END max_depth=10, min_data_in_leaf=600, num_leaves=20, verbose=-1;, score=0.673 total time=   1.0s
# [CV 4/5] END max_depth=10, min_data_in_leaf=600, num_leaves=20, verbose=-1;, score=0.680 total time=   1.0s
# [CV 5/5] END max_depth=10, min_data_in_leaf=600, num_leaves=20, verbose=-1;, score=0.665 total time=   1.0s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.705 total time=   1.7s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.682 total time=   1.7s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.677 total time=   1.7s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.683 total time=   1.8s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.673 total time=   1.7s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=20, verbose=-1;, score=0.696 total time=   1.0s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=20, verbose=-1;, score=0.684 total time=   1.0s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=20, verbose=-1;, score=0.671 total time=   1.0s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=20, verbose=-1;, score=0.680 total time=   1.0s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=20, verbose=-1;, score=0.666 total time=   1.0s
# [CV 1/5] END max_depth=10, min_data_in_leaf=400, num_leaves=10, verbose=-1;, score=0.687 total time=   0.8s
# [CV 2/5] END max_depth=10, min_data_in_leaf=400, num_leaves=10, verbose=-1;, score=0.673 total time=   0.8s
# [CV 3/5] END max_depth=10, min_data_in_leaf=400, num_leaves=10, verbose=-1;, score=0.670 total time=   0.9s
# [CV 4/5] END max_depth=10, min_data_in_leaf=400, num_leaves=10, verbose=-1;, score=0.674 total time=   0.8s
# [CV 5/5] END max_depth=10, min_data_in_leaf=400, num_leaves=10, verbose=-1;, score=0.658 total time=   0.8s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.700 total time=   1.3s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.683 total time=   1.3s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.671 total time=   1.3s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.681 total time=   1.3s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.675 total time=   1.3s
# [CV 1/5] END max_depth=20, min_data_in_leaf=300, num_leaves=60, verbose=-1;, score=0.701 total time=   1.6s
# [CV 2/5] END max_depth=20, min_data_in_leaf=300, num_leaves=60, verbose=-1;, score=0.677 total time=   1.6s
# [CV 3/5] END max_depth=20, min_data_in_leaf=300, num_leaves=60, verbose=-1;, score=0.669 total time=   1.5s
# [CV 4/5] END max_depth=20, min_data_in_leaf=300, num_leaves=60, verbose=-1;, score=0.681 total time=   1.5s
# [CV 5/5] END max_depth=20, min_data_in_leaf=300, num_leaves=60, verbose=-1;, score=0.670 total time=   1.6s
# [CV 1/5] END max_depth=20, min_data_in_leaf=100, num_leaves=30, verbose=-1;, score=0.697 total time=   1.1s
# [CV 2/5] END max_depth=20, min_data_in_leaf=100, num_leaves=30, verbose=-1;, score=0.679 total time=   1.1s
# [CV 3/5] END max_depth=20, min_data_in_leaf=100, num_leaves=30, verbose=-1;, score=0.666 total time=   1.2s
# [CV 4/5] END max_depth=20, min_data_in_leaf=100, num_leaves=30, verbose=-1;, score=0.684 total time=   1.1s
# [CV 5/5] END max_depth=20, min_data_in_leaf=100, num_leaves=30, verbose=-1;, score=0.670 total time=   1.2s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=20, verbose=-1;, score=0.695 total time=   1.0s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=20, verbose=-1;, score=0.675 total time=   1.0s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=20, verbose=-1;, score=0.674 total time=   1.0s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=20, verbose=-1;, score=0.683 total time=   1.0s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=20, verbose=-1;, score=0.662 total time=   1.1s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=20, verbose=-1;, score=0.697 total time=   1.4s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=20, verbose=-1;, score=0.683 total time=   1.1s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=20, verbose=-1;, score=0.675 total time=   1.0s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=20, verbose=-1;, score=0.684 total time=   1.1s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=20, verbose=-1;, score=0.666 total time=   1.1s
# [CV 1/5] END max_depth=10, min_data_in_leaf=200, num_leaves=40, verbose=-1;, score=0.697 total time=   1.3s
# [CV 2/5] END max_depth=10, min_data_in_leaf=200, num_leaves=40, verbose=-1;, score=0.680 total time=   1.3s
# [CV 3/5] END max_depth=10, min_data_in_leaf=200, num_leaves=40, verbose=-1;, score=0.671 total time=   1.3s
# [CV 4/5] END max_depth=10, min_data_in_leaf=200, num_leaves=40, verbose=-1;, score=0.680 total time=   1.3s
# [CV 5/5] END max_depth=10, min_data_in_leaf=200, num_leaves=40, verbose=-1;, score=0.672 total time=   1.3s
# [CV 1/5] END max_depth=10, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.697 total time=   1.2s
# [CV 2/5] END max_depth=10, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.686 total time=   1.2s
# [CV 3/5] END max_depth=10, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.673 total time=   1.2s
# [CV 4/5] END max_depth=10, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.685 total time=   1.2s
# [CV 5/5] END max_depth=10, min_data_in_leaf=900, num_leaves=30, verbose=-1;, score=0.674 total time=   1.2s
# [CV 1/5] END max_depth=10, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.703 total time=   1.3s
# [CV 2/5] END max_depth=10, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.682 total time=   1.3s
# [CV 3/5] END max_depth=10, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.675 total time=   1.3s
# [CV 4/5] END max_depth=10, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.683 total time=   1.3s
# [CV 5/5] END max_depth=10, min_data_in_leaf=400, num_leaves=40, verbose=-1;, score=0.669 total time=   1.3s
# [CV 1/5] END max_depth=20, min_data_in_leaf=700, num_leaves=20, verbose=-1;, score=0.692 total time=   1.0s
# [CV 2/5] END max_depth=20, min_data_in_leaf=700, num_leaves=20, verbose=-1;, score=0.685 total time=   1.1s
# [CV 3/5] END max_depth=20, min_data_in_leaf=700, num_leaves=20, verbose=-1;, score=0.669 total time=   1.0s
# [CV 4/5] END max_depth=20, min_data_in_leaf=700, num_leaves=20, verbose=-1;, score=0.679 total time=   1.1s
# [CV 5/5] END max_depth=20, min_data_in_leaf=700, num_leaves=20, verbose=-1;, score=0.668 total time=   1.0s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=80, verbose=-1;, score=0.697 total time=   1.8s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=80, verbose=-1;, score=0.681 total time=   1.8s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=80, verbose=-1;, score=0.670 total time=   1.9s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=80, verbose=-1;, score=0.688 total time=   1.8s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=80, verbose=-1;, score=0.674 total time=   1.9s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=700, num_leaves=70, verbose=-1;, score=0.695 total time=   1.9s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=700, num_leaves=70, verbose=-1;, score=0.683 total time=   1.9s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=700, num_leaves=70, verbose=-1;, score=0.675 total time=   1.9s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=700, num_leaves=70, verbose=-1;, score=0.687 total time=   1.9s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=700, num_leaves=70, verbose=-1;, score=0.678 total time=   1.9s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.682 total time=   0.9s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.673 total time=   0.9s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.670 total time=   0.9s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.678 total time=   0.9s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.660 total time=   0.9s
# [CV 1/5] END max_depth=10, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.682 total time=   0.9s
# [CV 2/5] END max_depth=10, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.675 total time=   0.9s
# [CV 3/5] END max_depth=10, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.668 total time=   1.0s
# [CV 4/5] END max_depth=10, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.673 total time=   1.0s
# [CV 5/5] END max_depth=10, min_data_in_leaf=600, num_leaves=10, verbose=-1;, score=0.658 total time=   1.0s
# [CV 1/5] END max_depth=10, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.702 total time=   1.8s
# [CV 2/5] END max_depth=10, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.680 total time=   1.8s
# [CV 3/5] END max_depth=10, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.667 total time=   1.9s
# [CV 4/5] END max_depth=10, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.683 total time=   1.9s
# [CV 5/5] END max_depth=10, min_data_in_leaf=200, num_leaves=70, verbose=-1;, score=0.678 total time=   1.9s
# [CV 1/5] END max_depth=20, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.698 total time=   2.4s
# [CV 2/5] END max_depth=20, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.683 total time=   2.5s
# [CV 3/5] END max_depth=20, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.673 total time=   2.9s
# [CV 4/5] END max_depth=20, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.689 total time=   2.8s
# [CV 5/5] END max_depth=20, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.673 total time=   3.1s
# [CV 1/5] END max_depth=10, min_data_in_leaf=700, num_leaves=30, verbose=-1;, score=0.701 total time=   2.3s
# [CV 2/5] END max_depth=10, min_data_in_leaf=700, num_leaves=30, verbose=-1;, score=0.686 total time=   2.4s
# [CV 3/5] END max_depth=10, min_data_in_leaf=700, num_leaves=30, verbose=-1;, score=0.672 total time=   2.5s
# [CV 4/5] END max_depth=10, min_data_in_leaf=700, num_leaves=30, verbose=-1;, score=0.685 total time=   2.5s
# [CV 5/5] END max_depth=10, min_data_in_leaf=700, num_leaves=30, verbose=-1;, score=0.670 total time=   2.4s
# [CV 1/5] END max_depth=20, min_data_in_leaf=900, num_leaves=70, verbose=-1;, score=0.698 total time=   3.6s
# [CV 2/5] END max_depth=20, min_data_in_leaf=900, num_leaves=70, verbose=-1;, score=0.683 total time=   4.0s
# [CV 3/5] END max_depth=20, min_data_in_leaf=900, num_leaves=70, verbose=-1;, score=0.672 total time=   4.1s
# [CV 4/5] END max_depth=20, min_data_in_leaf=900, num_leaves=70, verbose=-1;, score=0.685 total time=   4.3s
# [CV 5/5] END max_depth=20, min_data_in_leaf=900, num_leaves=70, verbose=-1;, score=0.674 total time=   4.3s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=40, verbose=-1;, score=0.704 total time=   3.5s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=40, verbose=-1;, score=0.681 total time=   3.4s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=40, verbose=-1;, score=0.675 total time=   3.5s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=40, verbose=-1;, score=0.688 total time=   3.1s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=900, num_leaves=40, verbose=-1;, score=0.678 total time=   3.0s
# [CV 1/5] END max_depth=10, min_data_in_leaf=500, num_leaves=10, verbose=-1;, score=0.683 total time=   2.0s
# [CV 2/5] END max_depth=10, min_data_in_leaf=500, num_leaves=10, verbose=-1;, score=0.676 total time=   2.2s
# [CV 3/5] END max_depth=10, min_data_in_leaf=500, num_leaves=10, verbose=-1;, score=0.665 total time=   2.0s
# [CV 4/5] END max_depth=10, min_data_in_leaf=500, num_leaves=10, verbose=-1;, score=0.675 total time=   1.7s
# [CV 5/5] END max_depth=10, min_data_in_leaf=500, num_leaves=10, verbose=-1;, score=0.659 total time=   1.7s
# [CV 1/5] END max_depth=10, min_data_in_leaf=400, num_leaves=50, verbose=-1;, score=0.700 total time=   2.6s
# [CV 2/5] END max_depth=10, min_data_in_leaf=400, num_leaves=50, verbose=-1;, score=0.682 total time=   2.5s
# [CV 3/5] END max_depth=10, min_data_in_leaf=400, num_leaves=50, verbose=-1;, score=0.675 total time=   2.5s
# [CV 4/5] END max_depth=10, min_data_in_leaf=400, num_leaves=50, verbose=-1;, score=0.682 total time=   2.4s
# [CV 5/5] END max_depth=10, min_data_in_leaf=400, num_leaves=50, verbose=-1;, score=0.672 total time=   2.4s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=80, verbose=-1;, score=0.698 total time=   3.2s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=80, verbose=-1;, score=0.681 total time=   3.1s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=80, verbose=-1;, score=0.667 total time=   3.0s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=80, verbose=-1;, score=0.685 total time=   3.1s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=200, num_leaves=80, verbose=-1;, score=0.680 total time=   3.0s
# [CV 1/5] END max_depth=20, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.706 total time=   2.8s
# [CV 2/5] END max_depth=20, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.683 total time=   2.8s
# [CV 3/5] END max_depth=20, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.669 total time=   2.8s
# [CV 4/5] END max_depth=20, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.689 total time=   2.8s
# [CV 5/5] END max_depth=20, min_data_in_leaf=400, num_leaves=70, verbose=-1;, score=0.672 total time=   2.7s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=50, verbose=-1;, score=0.699 total time=   2.4s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=50, verbose=-1;, score=0.688 total time=   2.3s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=50, verbose=-1;, score=0.675 total time=   2.4s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=50, verbose=-1;, score=0.687 total time=   2.3s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=800, num_leaves=50, verbose=-1;, score=0.675 total time=   2.3s
# [CV 1/5] END max_depth=20, min_data_in_leaf=100, num_leaves=60, verbose=-1;, score=0.693 total time=   2.3s
# [CV 2/5] END max_depth=20, min_data_in_leaf=100, num_leaves=60, verbose=-1;, score=0.684 total time=   2.3s
# [CV 3/5] END max_depth=20, min_data_in_leaf=100, num_leaves=60, verbose=-1;, score=0.672 total time=   2.3s
# [CV 4/5] END max_depth=20, min_data_in_leaf=100, num_leaves=60, verbose=-1;, score=0.681 total time=   2.3s
# [CV 5/5] END max_depth=20, min_data_in_leaf=100, num_leaves=60, verbose=-1;, score=0.674 total time=   2.2s
# [CV 1/5] END max_depth=-1, min_data_in_leaf=500, num_leaves=30, verbose=-1;, score=0.698 total time=   1.7s
# [CV 2/5] END max_depth=-1, min_data_in_leaf=500, num_leaves=30, verbose=-1;, score=0.685 total time=   1.8s
# [CV 3/5] END max_depth=-1, min_data_in_leaf=500, num_leaves=30, verbose=-1;, score=0.672 total time=   1.7s
# [CV 4/5] END max_depth=-1, min_data_in_leaf=500, num_leaves=30, verbose=-1;, score=0.685 total time=   1.7s
# [CV 5/5] END max_depth=-1, min_data_in_leaf=500, num_leaves=30, verbose=-1;, score=0.670 total time=   1.7s
# [CV 1/5] END max_depth=20, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.682 total time=   1.1s
# [CV 2/5] END max_depth=20, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.673 total time=   1.2s
# [CV 3/5] END max_depth=20, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.670 total time=   1.2s
# [CV 4/5] END max_depth=20, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.678 total time=   1.2s
# [CV 5/5] END max_depth=20, min_data_in_leaf=300, num_leaves=10, verbose=-1;, score=0.660 total time=   1.2s
# [CV 1/5] END max_depth=10, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.697 total time=   2.2s
# [CV 2/5] END max_depth=10, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.683 total time=   2.2s
# [CV 3/5] END max_depth=10, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.678 total time=   2.1s
# [CV 4/5] END max_depth=10, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.682 total time=   2.1s
# [CV 5/5] END max_depth=10, min_data_in_leaf=400, num_leaves=80, verbose=-1;, score=0.674 total time=   2.2s
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters found (based on combined AUC score): {'verbose': -1, 'num_leaves': 70, 'min_data_in_leaf': 800, 'max_depth': 10}
# Best combined AUC score (roc_auc + pr_auc): 0.6864055614287855

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lgbm.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, lgbm.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lgbm.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lgbm.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23779   184]
#  [  751   303]]
# roc auc: 0.9185
# pr auc: 0.4545

# %% [markdown]
# ## catboost

# %%
cb = CatBoostClassifier()
cb.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 cb = CatBoostClassifier()
#       2 cb.fit(x_train, y_train)
#
# NameError: name 'CatBoostClassifier' is not defined

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_auc_score, average_precision_score, make_scorer
import numpy as np

catboost_model = CatBoostClassifier(silent=True)

# Define the hyperparameter distribution
param_dist = {
    'depth': np.arange(4, 10),
    'learning_rate': np.linspace(0.01, 0.2, 10),
    'iterations': np.arange(100, 1000, 100)
}

# Custom scoring function that sums the roc_auc and pr_auc
def combined_auc_score(y_true, y_proba):
    roc_auc = roc_auc_score(y_true, y_proba)
    pr_auc = average_precision_score(y_true, y_proba)
    return (roc_auc + pr_auc)/2

# Create a custom scorer using make_scorer, with needs_proba=True since we need predicted probabilities
combined_scorer = make_scorer(combined_auc_score, needs_proba=True)

# Set up RandomizedSearchCV with the custom combined scorer
random_search = RandomizedSearchCV(
    estimator=catboost_model, 
    param_distributions=param_dist, 
    n_iter=50,
    scoring=combined_scorer, 
    cv=5, 
    random_state=42,
    verbose = 3
)

# Perform the random search
random_search.fit(x_train, y_train)

# Output the best parameters based on the combined auc score
print(f"Best parameters found (based on combined AUC score): {random_search.best_params_}")
print(f"Best combined AUC score (roc_auc + pr_auc): {random_search.best_score_}")

cb = random_search.best_estimator_
# Out:
# /home/fangyu.hoo/miniconda3/envs/search3/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END depth=6, iterations=500, learning_rate=0.2;, score=0.696 total time=   5.7s
# [CV 2/5] END depth=6, iterations=500, learning_rate=0.2;, score=0.677 total time=   5.5s
# [CV 3/5] END depth=6, iterations=500, learning_rate=0.2;, score=0.664 total time=   5.5s
# [CV 4/5] END depth=6, iterations=500, learning_rate=0.2;, score=0.685 total time=   5.5s
# [CV 5/5] END depth=6, iterations=500, learning_rate=0.2;, score=0.672 total time=   5.6s
# [CV 1/5] END depth=4, iterations=800, learning_rate=0.07333333333333333;, score=0.696 total time=   6.0s
# [CV 2/5] END depth=4, iterations=800, learning_rate=0.07333333333333333;, score=0.689 total time=   6.0s
# [CV 3/5] END depth=4, iterations=800, learning_rate=0.07333333333333333;, score=0.673 total time=   6.0s
# [CV 4/5] END depth=4, iterations=800, learning_rate=0.07333333333333333;, score=0.683 total time=   6.1s
# [CV 5/5] END depth=4, iterations=800, learning_rate=0.07333333333333333;, score=0.670 total time=   6.0s
# [CV 1/5] END depth=9, iterations=800, learning_rate=0.03111111111111111;, score=0.709 total time=  26.1s
# [CV 2/5] END depth=9, iterations=800, learning_rate=0.03111111111111111;, score=0.697 total time=  25.7s
# [CV 3/5] END depth=9, iterations=800, learning_rate=0.03111111111111111;, score=0.684 total time=  25.9s
# [CV 4/5] END depth=9, iterations=800, learning_rate=0.03111111111111111;, score=0.697 total time=  25.7s
# [CV 5/5] END depth=9, iterations=800, learning_rate=0.03111111111111111;, score=0.687 total time=  26.4s
# [CV 1/5] END depth=4, iterations=900, learning_rate=0.1366666666666667;, score=0.695 total time=   6.9s
# [CV 2/5] END depth=4, iterations=900, learning_rate=0.1366666666666667;, score=0.681 total time=   7.5s
# [CV 3/5] END depth=4, iterations=900, learning_rate=0.1366666666666667;, score=0.668 total time=   6.8s
# [CV 4/5] END depth=4, iterations=900, learning_rate=0.1366666666666667;, score=0.685 total time=   6.7s
# [CV 5/5] END depth=4, iterations=900, learning_rate=0.1366666666666667;, score=0.671 total time=   6.8s
# [CV 1/5] END depth=9, iterations=200, learning_rate=0.2;, score=0.684 total time=   6.5s
# [CV 2/5] END depth=9, iterations=200, learning_rate=0.2;, score=0.669 total time=   6.8s
# [CV 3/5] END depth=9, iterations=200, learning_rate=0.2;, score=0.665 total time=   6.7s
# [CV 4/5] END depth=9, iterations=200, learning_rate=0.2;, score=0.686 total time=   6.7s
# [CV 5/5] END depth=9, iterations=200, learning_rate=0.2;, score=0.665 total time=   6.7s
# [CV 1/5] END depth=4, iterations=800, learning_rate=0.1577777777777778;, score=0.693 total time=   6.1s
# [CV 2/5] END depth=4, iterations=800, learning_rate=0.1577777777777778;, score=0.678 total time=   6.1s
# [CV 3/5] END depth=4, iterations=800, learning_rate=0.1577777777777778;, score=0.664 total time=   6.1s
# [CV 4/5] END depth=4, iterations=800, learning_rate=0.1577777777777778;, score=0.683 total time=   6.0s
# [CV 5/5] END depth=4, iterations=800, learning_rate=0.1577777777777778;, score=0.669 total time=   6.1s
# [CV 1/5] END depth=7, iterations=300, learning_rate=0.1577777777777778;, score=0.693 total time=   4.4s
# [CV 2/5] END depth=7, iterations=300, learning_rate=0.1577777777777778;, score=0.679 total time=   4.4s
# [CV 3/5] END depth=7, iterations=300, learning_rate=0.1577777777777778;, score=0.676 total time=   4.4s
# [CV 4/5] END depth=7, iterations=300, learning_rate=0.1577777777777778;, score=0.683 total time=   4.4s
# [CV 5/5] END depth=7, iterations=300, learning_rate=0.1577777777777778;, score=0.677 total time=   4.4s
# [CV 1/5] END depth=8, iterations=600, learning_rate=0.1788888888888889;, score=0.694 total time=  12.4s
# [CV 2/5] END depth=8, iterations=600, learning_rate=0.1788888888888889;, score=0.687 total time=  12.2s
# [CV 3/5] END depth=8, iterations=600, learning_rate=0.1788888888888889;, score=0.664 total time=  12.2s
# [CV 4/5] END depth=8, iterations=600, learning_rate=0.1788888888888889;, score=0.677 total time=  12.2s
# [CV 5/5] END depth=8, iterations=600, learning_rate=0.1788888888888889;, score=0.670 total time=  12.2s
# [CV 1/5] END depth=7, iterations=800, learning_rate=0.052222222222222225;, score=0.706 total time=  11.4s
# [CV 2/5] END depth=7, iterations=800, learning_rate=0.052222222222222225;, score=0.695 total time=  11.6s
# [CV 3/5] END depth=7, iterations=800, learning_rate=0.052222222222222225;, score=0.678 total time=  11.5s
# [CV 4/5] END depth=7, iterations=800, learning_rate=0.052222222222222225;, score=0.698 total time=  11.7s
# [CV 5/5] END depth=7, iterations=800, learning_rate=0.052222222222222225;, score=0.682 total time=  11.6s
# [CV 1/5] END depth=8, iterations=300, learning_rate=0.07333333333333333;, score=0.702 total time=   6.2s
# [CV 2/5] END depth=8, iterations=300, learning_rate=0.07333333333333333;, score=0.687 total time=   6.2s
# [CV 3/5] END depth=8, iterations=300, learning_rate=0.07333333333333333;, score=0.678 total time=   6.1s
# [CV 4/5] END depth=8, iterations=300, learning_rate=0.07333333333333333;, score=0.692 total time=   6.1s
# [CV 5/5] END depth=8, iterations=300, learning_rate=0.07333333333333333;, score=0.684 total time=   6.3s
# [CV 1/5] END depth=4, iterations=100, learning_rate=0.1366666666666667;, score=0.681 total time=   0.9s
# [CV 2/5] END depth=4, iterations=100, learning_rate=0.1366666666666667;, score=0.667 total time=   0.9s
# [CV 3/5] END depth=4, iterations=100, learning_rate=0.1366666666666667;, score=0.654 total time=   0.9s
# [CV 4/5] END depth=4, iterations=100, learning_rate=0.1366666666666667;, score=0.661 total time=   0.9s
# [CV 5/5] END depth=4, iterations=100, learning_rate=0.1366666666666667;, score=0.654 total time=   0.9s
# [CV 1/5] END depth=5, iterations=300, learning_rate=0.1577777777777778;, score=0.699 total time=   2.9s
# [CV 2/5] END depth=5, iterations=300, learning_rate=0.1577777777777778;, score=0.686 total time=   2.9s
# [CV 3/5] END depth=5, iterations=300, learning_rate=0.1577777777777778;, score=0.675 total time=   2.8s
# [CV 4/5] END depth=5, iterations=300, learning_rate=0.1577777777777778;, score=0.688 total time=   2.8s
# [CV 5/5] END depth=5, iterations=300, learning_rate=0.1577777777777778;, score=0.670 total time=   2.7s
# [CV 1/5] END depth=8, iterations=600, learning_rate=0.01;, score=0.694 total time=  12.5s
# [CV 2/5] END depth=8, iterations=600, learning_rate=0.01;, score=0.683 total time=  12.2s
# [CV 3/5] END depth=8, iterations=600, learning_rate=0.01;, score=0.676 total time=  12.5s
# [CV 4/5] END depth=8, iterations=600, learning_rate=0.01;, score=0.679 total time=  12.5s
# [CV 5/5] END depth=8, iterations=600, learning_rate=0.01;, score=0.671 total time=  12.8s
# [CV 1/5] END depth=4, iterations=800, learning_rate=0.11555555555555555;, score=0.692 total time=   6.0s
# [CV 2/5] END depth=4, iterations=800, learning_rate=0.11555555555555555;, score=0.683 total time=   6.0s
# [CV 3/5] END depth=4, iterations=800, learning_rate=0.11555555555555555;, score=0.674 total time=   6.0s
# [CV 4/5] END depth=4, iterations=800, learning_rate=0.11555555555555555;, score=0.688 total time=   6.0s
# [CV 5/5] END depth=4, iterations=800, learning_rate=0.11555555555555555;, score=0.670 total time=   6.1s
# [CV 1/5] END depth=7, iterations=100, learning_rate=0.052222222222222225;, score=0.688 total time=   1.6s
# [CV 2/5] END depth=7, iterations=100, learning_rate=0.052222222222222225;, score=0.677 total time=   1.6s
# [CV 3/5] END depth=7, iterations=100, learning_rate=0.052222222222222225;, score=0.664 total time=   1.6s
# [CV 4/5] END depth=7, iterations=100, learning_rate=0.052222222222222225;, score=0.671 total time=   1.6s
# [CV 5/5] END depth=7, iterations=100, learning_rate=0.052222222222222225;, score=0.663 total time=   1.6s
# [CV 1/5] END depth=6, iterations=200, learning_rate=0.11555555555555555;, score=0.695 total time=   2.4s
# [CV 2/5] END depth=6, iterations=200, learning_rate=0.11555555555555555;, score=0.685 total time=   2.3s
# [CV 3/5] END depth=6, iterations=200, learning_rate=0.11555555555555555;, score=0.669 total time=   2.3s
# [CV 4/5] END depth=6, iterations=200, learning_rate=0.11555555555555555;, score=0.688 total time=   2.3s
# [CV 5/5] END depth=6, iterations=200, learning_rate=0.11555555555555555;, score=0.670 total time=   2.3s
# [CV 1/5] END depth=9, iterations=500, learning_rate=0.09444444444444444;, score=0.705 total time=  15.8s
# [CV 2/5] END depth=9, iterations=500, learning_rate=0.09444444444444444;, score=0.689 total time=  16.2s
# [CV 3/5] END depth=9, iterations=500, learning_rate=0.09444444444444444;, score=0.679 total time=  16.3s
# [CV 4/5] END depth=9, iterations=500, learning_rate=0.09444444444444444;, score=0.693 total time=  16.1s
# [CV 5/5] END depth=9, iterations=500, learning_rate=0.09444444444444444;, score=0.680 total time=  15.7s
# [CV 1/5] END depth=5, iterations=200, learning_rate=0.03111111111111111;, score=0.674 total time=   1.9s
# [CV 2/5] END depth=5, iterations=200, learning_rate=0.03111111111111111;, score=0.664 total time=   1.9s
# [CV 3/5] END depth=5, iterations=200, learning_rate=0.03111111111111111;, score=0.655 total time=   1.9s
# [CV 4/5] END depth=5, iterations=200, learning_rate=0.03111111111111111;, score=0.659 total time=   1.9s
# [CV 5/5] END depth=5, iterations=200, learning_rate=0.03111111111111111;, score=0.653 total time=   1.9s
# [CV 1/5] END depth=9, iterations=800, learning_rate=0.1366666666666667;, score=0.696 total time=  25.3s
# [CV 2/5] END depth=9, iterations=800, learning_rate=0.1366666666666667;, score=0.690 total time=  26.0s
# [CV 3/5] END depth=9, iterations=800, learning_rate=0.1366666666666667;, score=0.671 total time=  25.6s
# [CV 4/5] END depth=9, iterations=800, learning_rate=0.1366666666666667;, score=0.685 total time=  32.7s
# [CV 5/5] END depth=9, iterations=800, learning_rate=0.1366666666666667;, score=0.678 total time=  31.3s
# [CV 1/5] END depth=4, iterations=600, learning_rate=0.11555555555555555;, score=0.690 total time=   4.6s
# [CV 2/5] END depth=4, iterations=600, learning_rate=0.11555555555555555;, score=0.684 total time=   4.7s
# [CV 3/5] END depth=4, iterations=600, learning_rate=0.11555555555555555;, score=0.674 total time=   4.6s
# [CV 4/5] END depth=4, iterations=600, learning_rate=0.11555555555555555;, score=0.686 total time=   4.6s
# [CV 5/5] END depth=4, iterations=600, learning_rate=0.11555555555555555;, score=0.669 total time=   4.6s
# [CV 1/5] END depth=8, iterations=200, learning_rate=0.07333333333333333;, score=0.700 total time=   4.9s
# [CV 2/5] END depth=8, iterations=200, learning_rate=0.07333333333333333;, score=0.687 total time=   4.9s
# [CV 3/5] END depth=8, iterations=200, learning_rate=0.07333333333333333;, score=0.677 total time=   5.1s
# [CV 4/5] END depth=8, iterations=200, learning_rate=0.07333333333333333;, score=0.688 total time=   4.8s
# [CV 5/5] END depth=8, iterations=200, learning_rate=0.07333333333333333;, score=0.681 total time=   4.9s
# [CV 1/5] END depth=6, iterations=100, learning_rate=0.11555555555555555;, score=0.688 total time=   1.6s
# [CV 2/5] END depth=6, iterations=100, learning_rate=0.11555555555555555;, score=0.677 total time=   1.3s
# [CV 3/5] END depth=6, iterations=100, learning_rate=0.11555555555555555;, score=0.666 total time=   1.3s
# [CV 4/5] END depth=6, iterations=100, learning_rate=0.11555555555555555;, score=0.680 total time=   1.3s
# [CV 5/5] END depth=6, iterations=100, learning_rate=0.11555555555555555;, score=0.663 total time=   1.3s
# [CV 1/5] END depth=7, iterations=300, learning_rate=0.1788888888888889;, score=0.701 total time=   4.7s
# [CV 2/5] END depth=7, iterations=300, learning_rate=0.1788888888888889;, score=0.692 total time=   4.5s
# [CV 3/5] END depth=7, iterations=300, learning_rate=0.1788888888888889;, score=0.664 total time=   4.6s
# [CV 4/5] END depth=7, iterations=300, learning_rate=0.1788888888888889;, score=0.691 total time=   4.8s
# [CV 5/5] END depth=7, iterations=300, learning_rate=0.1788888888888889;, score=0.674 total time=   4.8s
# [CV 1/5] END depth=5, iterations=800, learning_rate=0.1577777777777778;, score=0.697 total time=   7.0s
# [CV 2/5] END depth=5, iterations=800, learning_rate=0.1577777777777778;, score=0.684 total time=   7.1s
# [CV 3/5] END depth=5, iterations=800, learning_rate=0.1577777777777778;, score=0.672 total time=   7.2s
# [CV 4/5] END depth=5, iterations=800, learning_rate=0.1577777777777778;, score=0.690 total time=   7.1s
# [CV 5/5] END depth=5, iterations=800, learning_rate=0.1577777777777778;, score=0.670 total time=   7.1s
# [CV 1/5] END depth=9, iterations=300, learning_rate=0.2;, score=0.684 total time=  12.4s
# [CV 2/5] END depth=9, iterations=300, learning_rate=0.2;, score=0.667 total time=  12.4s
# [CV 3/5] END depth=9, iterations=300, learning_rate=0.2;, score=0.662 total time=  12.5s
# [CV 4/5] END depth=9, iterations=300, learning_rate=0.2;, score=0.683 total time=  12.4s
# [CV 5/5] END depth=9, iterations=300, learning_rate=0.2;, score=0.665 total time=  12.4s
# [CV 1/5] END depth=4, iterations=100, learning_rate=0.052222222222222225;, score=0.667 total time=   0.9s
# [CV 2/5] END depth=4, iterations=100, learning_rate=0.052222222222222225;, score=0.649 total time=   0.9s
# [CV 3/5] END depth=4, iterations=100, learning_rate=0.052222222222222225;, score=0.637 total time=   0.9s
# [CV 4/5] END depth=4, iterations=100, learning_rate=0.052222222222222225;, score=0.643 total time=   0.9s
# [CV 5/5] END depth=4, iterations=100, learning_rate=0.052222222222222225;, score=0.634 total time=   0.9s
# [CV 1/5] END depth=6, iterations=100, learning_rate=0.01;, score=0.638 total time=   1.3s
# [CV 2/5] END depth=6, iterations=100, learning_rate=0.01;, score=0.605 total time=   1.3s
# [CV 3/5] END depth=6, iterations=100, learning_rate=0.01;, score=0.607 total time=   1.3s
# [CV 4/5] END depth=6, iterations=100, learning_rate=0.01;, score=0.610 total time=   1.3s
# [CV 5/5] END depth=6, iterations=100, learning_rate=0.01;, score=0.606 total time=   1.3s
# [CV 1/5] END depth=7, iterations=900, learning_rate=0.1577777777777778;, score=0.694 total time=  13.2s
# [CV 2/5] END depth=7, iterations=900, learning_rate=0.1577777777777778;, score=0.670 total time=  13.1s
# [CV 3/5] END depth=7, iterations=900, learning_rate=0.1577777777777778;, score=0.673 total time=  13.8s
# [CV 4/5] END depth=7, iterations=900, learning_rate=0.1577777777777778;, score=0.684 total time=  13.2s
# [CV 5/5] END depth=7, iterations=900, learning_rate=0.1577777777777778;, score=0.676 total time=  13.3s
# [CV 1/5] END depth=4, iterations=200, learning_rate=0.01;, score=0.638 total time=   1.6s
# [CV 2/5] END depth=4, iterations=200, learning_rate=0.01;, score=0.610 total time=   1.6s
# [CV 3/5] END depth=4, iterations=200, learning_rate=0.01;, score=0.608 total time=   1.6s
# [CV 4/5] END depth=4, iterations=200, learning_rate=0.01;, score=0.607 total time=   1.6s
# [CV 5/5] END depth=4, iterations=200, learning_rate=0.01;, score=0.607 total time=   1.7s
# [CV 1/5] END depth=7, iterations=500, learning_rate=0.03111111111111111;, score=0.700 total time=   7.9s
# [CV 2/5] END depth=7, iterations=500, learning_rate=0.03111111111111111;, score=0.692 total time=   8.0s
# [CV 3/5] END depth=7, iterations=500, learning_rate=0.03111111111111111;, score=0.676 total time=   8.0s
# [CV 4/5] END depth=7, iterations=500, learning_rate=0.03111111111111111;, score=0.689 total time=   7.9s
# [CV 5/5] END depth=7, iterations=500, learning_rate=0.03111111111111111;, score=0.675 total time=   7.9s
# [CV 1/5] END depth=8, iterations=200, learning_rate=0.03111111111111111;, score=0.693 total time=   5.0s
# [CV 2/5] END depth=8, iterations=200, learning_rate=0.03111111111111111;, score=0.683 total time=   5.0s
# [CV 3/5] END depth=8, iterations=200, learning_rate=0.03111111111111111;, score=0.673 total time=   5.1s
# [CV 4/5] END depth=8, iterations=200, learning_rate=0.03111111111111111;, score=0.678 total time=   5.1s
# [CV 5/5] END depth=8, iterations=200, learning_rate=0.03111111111111111;, score=0.672 total time=   5.0s
# [CV 1/5] END depth=5, iterations=900, learning_rate=0.1366666666666667;, score=0.701 total time=   7.9s
# [CV 2/5] END depth=5, iterations=900, learning_rate=0.1366666666666667;, score=0.685 total time=   8.1s
# [CV 3/5] END depth=5, iterations=900, learning_rate=0.1366666666666667;, score=0.674 total time=   8.0s
# [CV 4/5] END depth=5, iterations=900, learning_rate=0.1366666666666667;, score=0.690 total time=   7.9s
# [CV 5/5] END depth=5, iterations=900, learning_rate=0.1366666666666667;, score=0.671 total time=   8.1s
# [CV 1/5] END depth=6, iterations=700, learning_rate=0.11555555555555555;, score=0.702 total time=   8.2s
# [CV 2/5] END depth=6, iterations=700, learning_rate=0.11555555555555555;, score=0.685 total time=   8.2s
# [CV 3/5] END depth=6, iterations=700, learning_rate=0.11555555555555555;, score=0.673 total time=   8.1s
# [CV 4/5] END depth=6, iterations=700, learning_rate=0.11555555555555555;, score=0.695 total time=   8.1s
# [CV 5/5] END depth=6, iterations=700, learning_rate=0.11555555555555555;, score=0.674 total time=   8.1s
# [CV 1/5] END depth=9, iterations=200, learning_rate=0.09444444444444444;, score=0.702 total time=   8.7s
# [CV 2/5] END depth=9, iterations=200, learning_rate=0.09444444444444444;, score=0.689 total time=   8.7s
# [CV 3/5] END depth=9, iterations=200, learning_rate=0.09444444444444444;, score=0.675 total time=   8.7s
# [CV 4/5] END depth=9, iterations=200, learning_rate=0.09444444444444444;, score=0.689 total time=   8.8s
# [CV 5/5] END depth=9, iterations=200, learning_rate=0.09444444444444444;, score=0.677 total time=   8.7s
# [CV 1/5] END depth=7, iterations=800, learning_rate=0.2;, score=0.688 total time=  12.5s
# [CV 2/5] END depth=7, iterations=800, learning_rate=0.2;, score=0.673 total time=  12.6s
# [CV 3/5] END depth=7, iterations=800, learning_rate=0.2;, score=0.659 total time=  12.5s
# [CV 4/5] END depth=7, iterations=800, learning_rate=0.2;, score=0.677 total time=  12.6s
# [CV 5/5] END depth=7, iterations=800, learning_rate=0.2;, score=0.667 total time=  11.7s
# [CV 1/5] END depth=9, iterations=800, learning_rate=0.09444444444444444;, score=0.708 total time=  34.3s
# [CV 2/5] END depth=9, iterations=800, learning_rate=0.09444444444444444;, score=0.689 total time=  34.2s
# [CV 3/5] END depth=9, iterations=800, learning_rate=0.09444444444444444;, score=0.676 total time=  29.8s
# [CV 4/5] END depth=9, iterations=800, learning_rate=0.09444444444444444;, score=0.692 total time=  27.9s
# [CV 5/5] END depth=9, iterations=800, learning_rate=0.09444444444444444;, score=0.682 total time=  27.6s
# [CV 1/5] END depth=8, iterations=600, learning_rate=0.09444444444444444;, score=0.708 total time=  12.9s
# [CV 2/5] END depth=8, iterations=600, learning_rate=0.09444444444444444;, score=0.685 total time=  12.5s
# [CV 3/5] END depth=8, iterations=600, learning_rate=0.09444444444444444;, score=0.680 total time=  12.5s
# [CV 4/5] END depth=8, iterations=600, learning_rate=0.09444444444444444;, score=0.696 total time=  12.8s
# [CV 5/5] END depth=8, iterations=600, learning_rate=0.09444444444444444;, score=0.678 total time=  12.7s
# [CV 1/5] END depth=4, iterations=800, learning_rate=0.052222222222222225;, score=0.697 total time=   6.1s
# [CV 2/5] END depth=4, iterations=800, learning_rate=0.052222222222222225;, score=0.682 total time=   6.1s
# [CV 3/5] END depth=4, iterations=800, learning_rate=0.052222222222222225;, score=0.670 total time=   6.1s
# [CV 4/5] END depth=4, iterations=800, learning_rate=0.052222222222222225;, score=0.683 total time=   6.1s
# [CV 5/5] END depth=4, iterations=800, learning_rate=0.052222222222222225;, score=0.668 total time=   6.1s
# [CV 1/5] END depth=6, iterations=200, learning_rate=0.1366666666666667;, score=0.692 total time=   2.5s
# [CV 2/5] END depth=6, iterations=200, learning_rate=0.1366666666666667;, score=0.686 total time=   2.4s
# [CV 3/5] END depth=6, iterations=200, learning_rate=0.1366666666666667;, score=0.670 total time=   2.4s
# [CV 4/5] END depth=6, iterations=200, learning_rate=0.1366666666666667;, score=0.683 total time=   2.4s
# [CV 5/5] END depth=6, iterations=200, learning_rate=0.1366666666666667;, score=0.668 total time=   2.4s
# [CV 1/5] END depth=6, iterations=900, learning_rate=0.1788888888888889;, score=0.686 total time=  10.1s
# [CV 2/5] END depth=6, iterations=900, learning_rate=0.1788888888888889;, score=0.671 total time=  10.0s
# [CV 3/5] END depth=6, iterations=900, learning_rate=0.1788888888888889;, score=0.667 total time=  10.5s
# [CV 4/5] END depth=6, iterations=900, learning_rate=0.1788888888888889;, score=0.681 total time=  10.5s
# [CV 5/5] END depth=6, iterations=900, learning_rate=0.1788888888888889;, score=0.675 total time=  10.1s
# [CV 1/5] END depth=7, iterations=600, learning_rate=0.03111111111111111;, score=0.702 total time=   8.9s
# [CV 2/5] END depth=7, iterations=600, learning_rate=0.03111111111111111;, score=0.694 total time=   8.8s
# [CV 3/5] END depth=7, iterations=600, learning_rate=0.03111111111111111;, score=0.676 total time=   9.0s
# [CV 4/5] END depth=7, iterations=600, learning_rate=0.03111111111111111;, score=0.691 total time=   9.0s
# [CV 5/5] END depth=7, iterations=600, learning_rate=0.03111111111111111;, score=0.676 total time=   9.5s
# [CV 1/5] END depth=9, iterations=400, learning_rate=0.1788888888888889;, score=0.687 total time=  13.3s
# [CV 2/5] END depth=9, iterations=400, learning_rate=0.1788888888888889;, score=0.680 total time=  12.9s
# [CV 3/5] END depth=9, iterations=400, learning_rate=0.1788888888888889;, score=0.666 total time=  13.5s
# [CV 4/5] END depth=9, iterations=400, learning_rate=0.1788888888888889;, score=0.679 total time=  13.0s
# [CV 5/5] END depth=9, iterations=400, learning_rate=0.1788888888888889;, score=0.666 total time=  13.5s
# [CV 1/5] END depth=5, iterations=600, learning_rate=0.01;, score=0.678 total time=   5.2s
# [CV 2/5] END depth=5, iterations=600, learning_rate=0.01;, score=0.665 total time=   5.5s
# [CV 3/5] END depth=5, iterations=600, learning_rate=0.01;, score=0.656 total time=   5.3s
# [CV 4/5] END depth=5, iterations=600, learning_rate=0.01;, score=0.661 total time=   5.3s
# [CV 5/5] END depth=5, iterations=600, learning_rate=0.01;, score=0.654 total time=   5.4s
# [CV 1/5] END depth=9, iterations=100, learning_rate=0.1577777777777778;, score=0.695 total time=   3.6s
# [CV 2/5] END depth=9, iterations=100, learning_rate=0.1577777777777778;, score=0.683 total time=   3.6s
# [CV 3/5] END depth=9, iterations=100, learning_rate=0.1577777777777778;, score=0.673 total time=   3.5s
# [CV 4/5] END depth=9, iterations=100, learning_rate=0.1577777777777778;, score=0.686 total time=   3.5s
# [CV 5/5] END depth=9, iterations=100, learning_rate=0.1577777777777778;, score=0.676 total time=   3.5s
# [CV 1/5] END depth=5, iterations=900, learning_rate=0.07333333333333333;, score=0.703 total time=   7.9s
# [CV 2/5] END depth=5, iterations=900, learning_rate=0.07333333333333333;, score=0.690 total time=   7.9s
# [CV 3/5] END depth=5, iterations=900, learning_rate=0.07333333333333333;, score=0.675 total time=   7.9s
# [CV 4/5] END depth=5, iterations=900, learning_rate=0.07333333333333333;, score=0.690 total time=   8.0s
# [CV 5/5] END depth=5, iterations=900, learning_rate=0.07333333333333333;, score=0.673 total time=   7.9s
# [CV 1/5] END depth=4, iterations=800, learning_rate=0.2;, score=0.692 total time=   6.0s
# [CV 2/5] END depth=4, iterations=800, learning_rate=0.2;, score=0.682 total time=   6.0s
# [CV 3/5] END depth=4, iterations=800, learning_rate=0.2;, score=0.671 total time=   6.0s
# [CV 4/5] END depth=4, iterations=800, learning_rate=0.2;, score=0.686 total time=   6.1s
# [CV 5/5] END depth=4, iterations=800, learning_rate=0.2;, score=0.664 total time=   6.1s
# [CV 1/5] END depth=8, iterations=100, learning_rate=0.052222222222222225;, score=0.690 total time=   2.3s
# [CV 2/5] END depth=8, iterations=100, learning_rate=0.052222222222222225;, score=0.679 total time=   2.3s
# [CV 3/5] END depth=8, iterations=100, learning_rate=0.052222222222222225;, score=0.673 total time=   2.3s
# [CV 4/5] END depth=8, iterations=100, learning_rate=0.052222222222222225;, score=0.676 total time=   2.3s
# [CV 5/5] END depth=8, iterations=100, learning_rate=0.052222222222222225;, score=0.666 total time=   2.3s
# [CV 1/5] END depth=8, iterations=400, learning_rate=0.1366666666666667;, score=0.698 total time=   8.3s
# [CV 2/5] END depth=8, iterations=400, learning_rate=0.1366666666666667;, score=0.683 total time=   8.3s
# [CV 3/5] END depth=8, iterations=400, learning_rate=0.1366666666666667;, score=0.673 total time=   8.3s
# [CV 4/5] END depth=8, iterations=400, learning_rate=0.1366666666666667;, score=0.692 total time=   8.2s
# [CV 5/5] END depth=8, iterations=400, learning_rate=0.1366666666666667;, score=0.679 total time=   8.3s
# [CV 1/5] END depth=9, iterations=900, learning_rate=0.07333333333333333;, score=0.704 total time=  28.8s
# [CV 2/5] END depth=9, iterations=900, learning_rate=0.07333333333333333;, score=0.688 total time=  30.5s
# [CV 3/5] END depth=9, iterations=900, learning_rate=0.07333333333333333;, score=0.680 total time=  29.8s
# [CV 4/5] END depth=9, iterations=900, learning_rate=0.07333333333333333;, score=0.695 total time=  29.0s
# [CV 5/5] END depth=9, iterations=900, learning_rate=0.07333333333333333;, score=0.692 total time=  29.6s
# [CV 1/5] END depth=4, iterations=400, learning_rate=0.01;, score=0.656 total time=   3.1s
# [CV 2/5] END depth=4, iterations=400, learning_rate=0.01;, score=0.638 total time=   3.2s
# [CV 3/5] END depth=4, iterations=400, learning_rate=0.01;, score=0.633 total time=   3.0s
# [CV 4/5] END depth=4, iterations=400, learning_rate=0.01;, score=0.636 total time=   3.0s
# [CV 5/5] END depth=4, iterations=400, learning_rate=0.01;, score=0.628 total time=   3.0s
# Best parameters found (based on combined AUC score): {'learning_rate': 0.03111111111111111, 'iterations': 800, 'depth': 9}
# Best combined AUC score (roc_auc + pr_auc): 0.6950295888362936

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, cb.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, cb.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, cb.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, cb.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23815   148]
#  [  750   304]]
# roc auc: 0.9269
# pr auc: 0.4978

# %% [markdown]
# # scaled dataset
# -- attempted both StandardScaler and MinMaxScaler, no significant improvement in performances observed

# %%
# scaler = StandardScaler()
scaler = MinMaxScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## logistic regression

# %%
lr = LogisticRegression()
lr.fit(x_train_scaled, y_train)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lr.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, lr.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lr.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lr.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23934    29]
#  [ 1021    33]]
# roc auc: 0.8475
# pr auc: 0.2491

# %% [markdown]
# ## decision tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, dt.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, dt.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, dt.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, dt.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23040   923]
#  [  732   322]]
# roc auc: 0.6335
# pr auc: 0.2967

# %% [markdown]
# ## random forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train_scaled, y_train)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, rf.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, rf.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, rf.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, rf.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23901    62]
#  [  897   157]]
# roc auc: 0.8954
# pr auc: 0.44

# %% [markdown]
# ## xgboost

# %%
xgb = XGBClassifier()
xgb.fit(x_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, xgb.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, xgb.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, xgb.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, xgb.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23741   222]
#  [  747   307]]
# roc auc: 0.9112
# pr auc: 0.4257

# %% [markdown]
# ## lightgbm

# %%
lgbm = LGBMClassifier()
lgbm.fit(x_train_scaled, y_train)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 4421, number of negative: 92400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015287 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27965
# [LightGBM] [Info] Number of data points in the train set: 96821, number of used features: 113
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.045662 -> initscore=-3.039761
# [LightGBM] [Info] Start training from score -3.039761
# LGBMClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lgbm.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, lgbm.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lgbm.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lgbm.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23778   185]
#  [  743   311]]
# roc auc: 0.9194
# pr auc: 0.4621

# %% [markdown]
# ## catboost

# %%
cb = CatBoostClassifier()
cb.fit(x_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[128], line 1
#
# ----> 1 cb = CatBoostClassifier()
#
#       2 cb.fit(x_train, y_train)
#
#
#
# NameError: name 'CatBoostClassifier' is not defined

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, cb.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, cb.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, cb.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, cb.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')

# %% [markdown]
# # oversampling (class 1)
# -- no significant improvements for default params, mainly increase in AUC values (both ROC and PR) for decision tree, but in general lower accuracy observed across all 4 models
#
# -- also tested ADASYN (different oversampling technique), similar results obtained but slightly worse than SMOTE

# %%
Counter(y_train.label)
# Out:
# Counter({0: 92400, 1: 4421})

# %%
# sm = SMOTE()
sm = ADASYN()
x_train_sm, y_train_sm = sm.fit_resample(x_train, y_train)

# %%
Counter(y_train_sm.label)
# Out:
# Counter({0: 92400, 1: 92400})

# %% [markdown]
# ## logistic regression

# %%
lr = LogisticRegression()
lr.fit(x_train_sm, y_train_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lr.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, lr.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lr.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lr.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[17663  6300]
#  [  282   772]]
# roc auc: 0.8102
# pr auc: 0.2057

# %% [markdown]
# ## decision tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train_sm, y_train_sm)
# Out:
# DecisionTreeClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, dt.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, dt.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, dt.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, dt.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[21918  2045]
#  [  660   394]]
# roc auc: 0.6442
# pr auc: 0.2809

# %% [markdown]
# ## random forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train_sm, y_train_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, rf.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, rf.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, rf.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, rf.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23485   478]
#  [  612   442]]
# roc auc: 0.9132
# pr auc: 0.421

# %% [markdown]
# ## xgboost

# %%
xgb = XGBClassifier()
xgb.fit(x_train_sm, y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, xgb.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, xgb.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, xgb.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, xgb.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23508   455]
#  [  705   349]]
# roc auc: 0.8917
# pr auc: 0.3385

# %% [markdown]
# ## lightgbm

# %%
lgbm = LGBMClassifier()
lgbm.fit(x_train_sm, y_train_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 93014, number of negative: 92400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28815
# [LightGBM] [Info] Number of data points in the train set: 185414, number of used features: 113
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501656 -> initscore=0.006623
# [LightGBM] [Info] Start training from score 0.006623
# LGBMClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lgbm.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, lgbm.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lgbm.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lgbm.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23494   469]
#  [  759   295]]
# roc auc: 0.882
# pr auc: 0.2926

# %% [markdown]
# ## catboost

# %%
cb = CatBoostClassifier()
cb.fit(x_train_sm, y_train_sm)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[128], line 1
#
# ----> 1 cb = CatBoostClassifier()
#
#       2 cb.fit(x_train, y_train)
#
#
#
# NameError: name 'CatBoostClassifier' is not defined

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, cb.predict(x_test))}')
# print(f'accuracy: {round(accuracy_score(y_test, cb.predict(x_test)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, cb.predict_proba(x_test)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, cb.predict_proba(x_test)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')

# %% [markdown]
# # scaling > oversampling
# -- using standardscaler and smote since the individual components perform better than minmaxscaler and adasyn respectively

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
Counter(y_train.label)
# Out:
# Counter({0: 92400, 1: 4421})

# %%
sm = SMOTE()
x_train_scaled_sm, y_train_scaled_sm = sm.fit_resample(x_train_scaled, y_train)

# %%
Counter(y_train_sm.label)
# Out:
# Counter({0: 92400, 1: 92400})

# %% [markdown]
# ## logistic regression

# %%
lr = LogisticRegression()
lr.fit(x_train_scaled_sm, y_train_scaled_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lr.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, lr.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lr.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lr.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[18707  5256]
#  [  244   810]]
# roc auc: 0.8531
# pr auc: 0.2278

# %% [markdown]
# ## decision tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train_scaled_sm, y_train_scaled_sm)
# Out:
# DecisionTreeClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, dt.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, dt.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, dt.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, dt.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[21848  2115]
#  [  586   468]]
# roc auc: 0.6779
# pr auc: 0.3243

# %% [markdown]
# ## random forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train_scaled_sm, y_train_scaled_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, rf.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, rf.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, rf.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, rf.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23396   567]
#  [  551   503]]
# roc auc: 0.9164
# pr auc: 0.4316

# %% [markdown]
# ## xgboost

# %%
xgb = XGBClassifier()
xgb.fit(x_train_scaled_sm, y_train_scaled_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, xgb.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, xgb.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, xgb.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, xgb.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23533   430]
#  [  687   367]]
# roc auc: 0.8916
# pr auc: 0.3732

# %% [markdown]
# ## lightgbm

# %%
lgbm = LGBMClassifier()
lgbm.fit(x_train_scaled_sm, y_train_scaled_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 92400, number of negative: 92400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031277 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28815
# [LightGBM] [Info] Number of data points in the train set: 184800, number of used features: 113
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# LGBMClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lgbm.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, lgbm.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lgbm.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lgbm.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23503   460]
#  [  710   344]]
# roc auc: 0.8929
# pr auc: 0.3381

# %% [markdown]
# ## catboost

# %%
cb = CatBoostClassifier()
cb.fit(x_train_scaled_sm, y_train_scaled_sm)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[128], line 1
#
# ----> 1 cb = CatBoostClassifier()
#
#       2 cb.fit(x_train, y_train)
#
#
#
# NameError: name 'CatBoostClassifier' is not defined

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, cb.predict(x_test_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, cb.predict(x_test_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, cb.predict_proba(x_test_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, cb.predict_proba(x_test_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')

# %% [markdown]
# # oversampling > scaling

# %%
Counter(y_train.label)
# Out:
# Counter({0: 92400, 1: 4421})

# %%
sm = SMOTE()
x_train_sm, y_train_sm = sm.fit_resample(x_train, y_train)

# %%
Counter(y_train_sm.label)
# Out:
# Counter({0: 92400, 1: 92400})

# %%
scaler = StandardScaler()
x_train_sm_scaled = scaler.fit_transform(x_train_sm)
x_test_sm_scaled = scaler.transform(x_test)

# %% [markdown]
# ## logistic regression

# %%
lr = LogisticRegression()
lr.fit(x_train_sm_scaled, y_train_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lr.predict(x_test_sm_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, lr.predict(x_test_sm_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lr.predict_proba(x_test_sm_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lr.predict_proba(x_test_sm_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[18595  5368]
#  [  231   823]]
# roc auc: 0.855
# pr auc: 0.2286

# %% [markdown]
# ## decision tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train_sm_scaled, y_train_sm)
# Out:
# DecisionTreeClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, dt.predict(x_test_sm_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, dt.predict(x_test_sm_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, dt.predict_proba(x_test_sm_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, dt.predict_proba(x_test_sm_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[21951  2012]
#  [  579   475]]
# roc auc: 0.6834
# pr auc: 0.3324

# %% [markdown]
# ## random forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train_sm_scaled, y_train_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, rf.predict(x_test_sm_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, rf.predict(x_test_sm_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, rf.predict_proba(x_test_sm_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, rf.predict_proba(x_test_sm_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23476   487]
#  [  598   456]]
# roc auc: 0.9173
# pr auc: 0.4353

# %% [markdown]
# ## xgboost

# %%
xgb = XGBClassifier()
xgb.fit(x_train_sm_scaled, y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, xgb.predict(x_test_sm_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, xgb.predict(x_test_sm_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, xgb.predict_proba(x_test_sm_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, xgb.predict_proba(x_test_sm_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23524   439]
#  [  688   366]]
# roc auc: 0.8946
# pr auc: 0.3677

# %% [markdown]
# ## lightgbm

# %%
lgbm = LGBMClassifier()
lgbm.fit(x_train_sm_scaled, y_train_sm)
# Out:
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/leeeda/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 92400, number of negative: 92400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028959 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28815
# [LightGBM] [Info] Number of data points in the train set: 184800, number of used features: 113
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# LGBMClassifier()

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, lgbm.predict(x_test_sm_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, lgbm.predict(x_test_sm_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, lgbm.predict_proba(x_test_sm_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, lgbm.predict_proba(x_test_sm_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')
# Out:
# confusion matrix:
#  [[23494   469]
#  [  720   334]]
# roc auc: 0.8884
# pr auc: 0.3204

# %% [markdown]
# ## catboost

# %%
cb = CatBoostClassifier()
cb.fit(x_train_sm_scaled, y_train_sm)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[128], line 1
#
# ----> 1 cb = CatBoostClassifier()
#
#       2 cb.fit(x_train, y_train)
#
#
#
# NameError: name 'CatBoostClassifier' is not defined

# %%
print(f'confusion matrix:\n {confusion_matrix(y_test, cb.predict(x_test_sm_scaled))}')
# print(f'accuracy: {round(accuracy_score(y_test, cb.predict(x_test_sm_scaled)),4)}')
print(f'roc auc: {round(roc_auc_score(y_test, cb.predict_proba(x_test_sm_scaled)[:,1]),4)}')

precision, recall, thresholds = precision_recall_curve(y_test, cb.predict_proba(x_test_sm_scaled)[:,1])
print(f'pr auc: {round(auc(recall, precision),4)}')

# %% [markdown]
# # end
